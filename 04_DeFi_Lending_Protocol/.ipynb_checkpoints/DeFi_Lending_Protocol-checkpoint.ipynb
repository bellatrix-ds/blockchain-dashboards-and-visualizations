# %% [markdown]
# # Part 1: TVL

# %%
import pandas as pd
import json
import requests

# Option 1: Load from file
with open('aave.json', 'r') as f:
    data = json.load(f)

# Option 2: Fetch directly from API
# response = requests.get('https://api.llama.fi/protocol/aave-v3')
# data = response.json()

# Extract ALL data from chainTvls branch
chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    # chain_data is a dictionary that may contain multiple keys like 'tvl', 'tokensInUsd', 'tokens', etc.
    
    # Check if there's a 'tvl' array
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    # Check if there are other arrays (tokensInUsd, tokens, etc.)
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                # Add all other fields from the entry
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

# Create DataFrame with all chainTvls data
df_chain_tvls = pd.DataFrame(chain_tvls_data)

# %%
df_chain_tvls
# Out:
#                   chain metric_type                date  totalLiquidityUSD
# 0      Ethereum-staking         tvl 2020-12-03 00:00:00          244094753
# 1      Ethereum-staking         tvl 2020-12-04 00:00:00          243189473
# 2      Ethereum-staking         tvl 2020-12-05 00:00:00          250327449
# 3      Ethereum-staking         tvl 2020-12-06 00:00:00          253742514
# 4      Ethereum-staking         tvl 2020-12-07 00:00:00          256062919
# ...                 ...         ...                 ...                ...
# 43314    Aptos-borrowed         tvl 2026-01-07 00:00:00           15965898
# 43315    Aptos-borrowed         tvl 2026-01-08 00:00:00           15977650
# 43316    Aptos-borrowed         tvl 2026-01-09 00:00:00           15998925
# 43317    Aptos-borrowed         tvl 2026-01-10 00:00:00           16014125
# 43318    Aptos-borrowed         tvl 2026-01-10 15:28:59           16017944
#
# [43319 rows x 4 columns]

# %%
#df_chain_tvls['chain'].value_counts()
df_chain_tvls['date'].max()
# Out:
# Timestamp('2026-01-10 15:28:59')

# %%
import pandas as pd
import json
import requests

response = requests.get('https://api.llama.fi/protocol/aave')
data = response.json()

chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

df_chain_tvls_aave = pd.DataFrame(chain_tvls_data)
df_chain_tvls_aave['protocol'] = 'Aave'

# %%
df_chain_tvls_aave
# Out:
#                   chain metric_type                date  totalLiquidityUSD  \
# 0      Ethereum-staking         tvl 2020-12-03 00:00:00          244094753
# 1      Ethereum-staking         tvl 2020-12-04 00:00:00          243189473
# 2      Ethereum-staking         tvl 2020-12-05 00:00:00          250327449
# 3      Ethereum-staking         tvl 2020-12-06 00:00:00          253742514
# 4      Ethereum-staking         tvl 2020-12-07 00:00:00          256062919
# ...                 ...         ...                 ...                ...
# 43314    Aptos-borrowed         tvl 2026-01-07 00:00:00           15965898
# 43315    Aptos-borrowed         tvl 2026-01-08 00:00:00           15977650
# 43316    Aptos-borrowed         tvl 2026-01-09 00:00:00           15998925
# 43317    Aptos-borrowed         tvl 2026-01-10 00:00:00           16014125
# 43318    Aptos-borrowed         tvl 2026-01-10 22:21:11           16014540
#
#       protocol
# 0         Aave
# 1         Aave
# 2         Aave
# 3         Aave
# 4         Aave
# ...        ...
# 43314     Aave
# 43315     Aave
# 43316     Aave
# 43317     Aave
# 43318     Aave
#
# [43319 rows x 5 columns]

# %% [markdown]
# # Sky TVL

# %%
# sky
import pandas as pd
import json
import requests

response = requests.get('https://api.llama.fi/protocol/sky')
data = response.json()

chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

df_chain_tvls_sky = pd.DataFrame(chain_tvls_data)

# %%
df_chain_tvls_sky['protocol'] = 'Sky'

# %%
df_chain_tvls_sky
# Out:
#                  chain metric_type                date  totalLiquidityUSD  \
# 0     Ethereum-staking         tvl 2025-07-18 00:00:00            3704859
# 1     Ethereum-staking         tvl 2025-07-19 00:00:00            4302784
# 2     Ethereum-staking         tvl 2025-07-20 00:00:00            4335895
# 3     Ethereum-staking         tvl 2025-07-21 00:00:00            5019894
# 4     Ethereum-staking         tvl 2025-07-22 00:00:00          263747955
# ...                ...         ...                 ...                ...
# 2916           staking         tvl 2026-01-07 00:00:00          446985990
# 2917           staking         tvl 2026-01-08 00:00:00          429509803
# 2918           staking         tvl 2026-01-09 00:00:00          406319487
# 2919           staking         tvl 2026-01-10 00:00:00          427213819
# 2920           staking         tvl 2026-01-10 21:47:59          451012425
#
#      protocol
# 0         Sky
# 1         Sky
# 2         Sky
# 3         Sky
# 4         Sky
# ...       ...
# 2916      Sky
# 2917      Sky
# 2918      Sky
# 2919      Sky
# 2920      Sky
#
# [2921 rows x 5 columns]

# %%
test = df_chain_tvls_sky.groupby(['chain'])['totalLiquidityUSD'].sum()

# %%
test
# Out:
# chain
# Ethereum            16772435715183
# Ethereum-staking       71791206268
# staking                71791206268
# Name: totalLiquidityUSD, dtype: int64

# %% [markdown]
# # Morpho

# %%
response = requests.get('https://api.llama.fi/protocol/morpho')
data = response.json()

chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

df_chain_tvls_morpho = pd.DataFrame(chain_tvls_data)
df_chain_tvls_morpho['protocol'] = 'Morpho'

# %%
df_chain_tvls_morpho
# Out:
#                          chain metric_type                date  \
# 0            Ethereum-borrowed         tvl 2022-08-19 00:00:00
# 1            Ethereum-borrowed         tvl 2022-08-20 00:00:00
# 2            Ethereum-borrowed         tvl 2022-08-21 00:00:00
# 3            Ethereum-borrowed         tvl 2022-08-22 00:00:00
# 4            Ethereum-borrowed         tvl 2022-08-23 00:00:00
# ...                        ...         ...                 ...
# 17745  Hyperliquid L1-borrowed         tvl 2026-01-07 00:00:00
# 17746  Hyperliquid L1-borrowed         tvl 2026-01-08 00:00:00
# 17747  Hyperliquid L1-borrowed         tvl 2026-01-09 00:00:00
# 17748  Hyperliquid L1-borrowed         tvl 2026-01-10 00:00:00
# 17749  Hyperliquid L1-borrowed         tvl 2026-01-10 21:43:59
#
#        totalLiquidityUSD protocol
# 0               97429448   Morpho
# 1               97366284   Morpho
# 2               96929579   Morpho
# 3               98655595   Morpho
# 4               99745630   Morpho
# ...                  ...      ...
# 17745          156144844   Morpho
# 17746          153014533   Morpho
# 17747          151532808   Morpho
# 17748          145624799   Morpho
# 17749          140519472   Morpho
#
# [17750 rows x 5 columns]

# %%
print(df_chain_tvls_morpho.groupby(['chain'])['totalLiquidityUSD'].sum().head(10))
# Out:
# chain
# Abstract                     6875
# Abstract-borrowed            1390
# Arbitrum              21751750055
# Arbitrum-borrowed     16754347440
# BSC                          2285
# BSC-borrowed                  309
# Base                 500717914019
# Base-borrowed        257763043830
# Bitlayer                        0
# Bitlayer-borrowed               0
# Name: totalLiquidityUSD, dtype: int64

# %% [markdown]
# # SparkLend

# %%
response = requests.get('https://api.llama.fi/protocol/sparkLend')
data = response.json()

chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

df_chain_tvls_sparkLend = pd.DataFrame(chain_tvls_data)
df_chain_tvls_sparkLend['protocol'] = 'SparkLend'

# %%
df_chain_tvls_sparkLend
# Out:
#                   chain metric_type                date  totalLiquidityUSD  \
# 0      Ethereum-staking         tvl 2025-07-22 00:00:00          8015955.0
# 1      Ethereum-staking         tvl 2025-07-23 00:00:00         11591247.0
# 2      Ethereum-staking         tvl 2025-07-24 00:00:00         23133313.0
# 3      Ethereum-staking         tvl 2025-07-25 00:00:00         14986620.0
# 4      Ethereum-staking         tvl 2025-07-26 00:00:00         16395330.0
# ...                 ...         ...                 ...                ...
# 15076          borrowed      tokens 2026-01-07 00:00:00                NaN
# 15077          borrowed      tokens 2026-01-08 00:00:00                NaN
# 15078          borrowed      tokens 2026-01-09 00:00:00                NaN
# 15079          borrowed      tokens 2026-01-10 00:00:00                NaN
# 15080          borrowed      tokens 2026-01-10 21:49:59                NaN
#
#                                                   tokens   protocol
# 0                                                    NaN  SparkLend
# 1                                                    NaN  SparkLend
# 2                                                    NaN  SparkLend
# 3                                                    NaN  SparkLend
# 4                                                    NaN  SparkLend
# ...                                                  ...        ...
# 15076  {'DAI': 262220671.20353, 'USDC': 42967289.5138...  SparkLend
# 15077  {'DAI': 257348583.90369, 'USDC': 42863745.1682...  SparkLend
# 15078  {'DAI': 252089251.0627, 'USDC': 41513520.06169...  SparkLend
# 15079  {'DAI': 251972349.19266, 'USDC': 41544618.1811...  SparkLend
# 15080  {'DAI': 252002125.14453, 'USDC': 41549344.1604...  SparkLend
#
# [15081 rows x 6 columns]

# %%
print(df_chain_tvls_sparkLend.groupby(['chain'])['totalLiquidityUSD'].sum().head(10))
# Out:
# chain
# Ethereum             2.550233e+12
# Ethereum-borrowed    1.335214e+12
# Ethereum-staking     2.526808e+09
# borrowed             1.338466e+12
# staking              2.526808e+09
# xDai                 2.750562e+10
# xDai-borrowed        3.251406e+09
# Name: totalLiquidityUSD, dtype: float64

# %% [markdown]
# # Compound

# %%
response = requests.get('https://api.llama.fi/protocol/compound-V3')
data = response.json()

chain_tvls_data = []

for chain_key, chain_data in data.get('chainTvls', {}).items():
    if 'tvl' in chain_data and isinstance(chain_data['tvl'], list):
        for entry in chain_data['tvl']:
            chain_tvls_data.append({
                'chain': chain_key,
                'metric_type': 'tvl',
                'date': pd.to_datetime(entry['date'], unit='s'),
                'totalLiquidityUSD': entry.get('totalLiquidityUSD')
            })
    
    for key, value in chain_data.items():
        if key != 'tvl' and isinstance(value, list):
            for entry in value:
                record = {
                    'chain': chain_key,
                    'metric_type': key,
                    'date': pd.to_datetime(entry.get('date'), unit='s') if 'date' in entry else None
                }
                for field, field_value in entry.items():
                    if field != 'date':
                        record[field] = field_value
                chain_tvls_data.append(record)

df_chain_tvls_compound = pd.DataFrame(chain_tvls_data)
df_chain_tvls_compound['protocol'] = 'Compound'

# %%
df_chain_tvls_compound = df_chain_tvls_compound[df_chain_tvls_compound['metric_type']=='tvl']
df_chain_tvls_compound
# Out:
#                   chain metric_type                date  totalLiquidityUSD  \
# 0      Polygon-borrowed         tvl 2023-03-07 00:00:00                0.0
# 1      Polygon-borrowed         tvl 2023-03-08 00:00:00             1002.0
# 2      Polygon-borrowed         tvl 2023-03-09 00:00:00          2394113.0
# 3      Polygon-borrowed         tvl 2023-03-10 00:00:00          2497631.0
# 4      Polygon-borrowed         tvl 2023-03-11 00:00:00          2841472.0
# ...                 ...         ...                 ...                ...
# 39287          borrowed         tvl 2026-01-07 00:00:00        862194481.0
# 39288          borrowed         tvl 2026-01-08 00:00:00        854985311.0
# 39289          borrowed         tvl 2026-01-09 00:00:00        851383924.0
# 39290          borrowed         tvl 2026-01-10 00:00:00        851742257.0
# 39291          borrowed         tvl 2026-01-10 23:00:59        851050608.0
#
#       tokens  protocol
# 0        NaN  Compound
# 1        NaN  Compound
# 2        NaN  Compound
# 3        NaN  Compound
# 4        NaN  Compound
# ...      ...       ...
# 39287    NaN  Compound
# 39288    NaN  Compound
# 39289    NaN  Compound
# 39290    NaN  Compound
# 39291    NaN  Compound
#
# [13920 rows x 6 columns]

# %%
df_chain_tvls_compound['chain'].value_counts()
# Out:
# chain
# borrowed             1234
# Ethereum-borrowed    1234
# Ethereum             1234
# Polygon              1042
# Polygon-borrowed     1042
# Arbitrum-borrowed     971
# Arbitrum              971
# Base-borrowed         881
# Base                  881
# Scroll-borrowed       642
# Scroll                642
# Optimism-borrowed     629
# Optimism              629
# Mantle-borrowed       397
# Mantle                397
# Ronin-borrowed        277
# Ronin                 277
# Unichain              270
# Unichain-borrowed     270
# Name: count, dtype: int64

# %% [markdown]
# # Concat TVL Data

# %%
df_chain_tvls_morpho.head(1)
# Out:
#                chain metric_type       date  totalLiquidityUSD protocol
# 0  Ethereum-borrowed         tvl 2022-08-19           97429448   Morpho

# %%
df_chain_tvls_sparkLend.head(1)
# Out:
#               chain metric_type       date  totalLiquidityUSD tokens  \
# 0  Ethereum-staking         tvl 2025-07-22          8015955.0    NaN
#
#     protocol
# 0  SparkLend

# %%
# Combine all into one DataFrame
df_all = pd.concat([
df_chain_tvls_aave,
df_chain_tvls_compound,
df_chain_tvls_sky,
df_chain_tvls_morpho,
df_chain_tvls_sparkLend
], ignore_index=True)

# %%
df_all = df_all[df_all['metric_type'] == 'tvl' ]
df_all = df_all[df_all['date'] >= '2025-01-01']
df_all
# Out:
#                   chain metric_type                date  totalLiquidityUSD  \
# 1490   Ethereum-staking         tvl 2025-01-01 00:00:00        879,928,400
# 1491   Ethereum-staking         tvl 2025-01-02 00:00:00        912,779,100
# 1492   Ethereum-staking         tvl 2025-01-03 00:00:00        933,418,907
# 1493   Ethereum-staking         tvl 2025-01-04 00:00:00        983,208,496
# 1494   Ethereum-staking         tvl 2025-01-05 00:00:00        983,594,443
# ...                 ...         ...                 ...                ...
# 91012          borrowed         tvl 2026-01-07 00:00:00      1,500,505,496
# 91013          borrowed         tvl 2026-01-08 00:00:00      1,433,911,733
# 91014          borrowed         tvl 2026-01-09 00:00:00      1,513,419,278
# 91015          borrowed         tvl 2026-01-10 00:00:00      1,500,386,130
# 91016          borrowed         tvl 2026-01-10 21:49:59      1,503,305,163
#
#         protocol tokens
# 1490        Aave    NaN
# 1491        Aave    NaN
# 1492        Aave    NaN
# 1493        Aave    NaN
# 1494        Aave    NaN
# ...          ...    ...
# 91012  SparkLend    NaN
# 91013  SparkLend    NaN
# 91014  SparkLend    NaN
# 91015  SparkLend    NaN
# 91016  SparkLend    NaN
#
# [38876 rows x 6 columns]

# %%
df_all['protocol'].value_counts()
# Out:
# protocol
# Morpho       14738
# Aave         14444
# Compound      6734
# SparkLend     2228
# Sky            732
# Name: count, dtype: int64

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)

# %%
df_all_finall = df_all[df_all['chain'].isin(["Ethereum", "Arbitrum", "Base","Plasma","Polygon",
                                            "Optimism"])]

# %%
df_all_finall
# Out:
#           chain metric_type                date  totalLiquidityUSD   protocol  \
# 8740   Ethereum         tvl 2025-01-01 00:00:00     17,644,399,434       Aave
# 8741   Ethereum         tvl 2025-01-02 00:00:00     18,004,246,322       Aave
# 8742   Ethereum         tvl 2025-01-03 00:00:00     18,259,385,558       Aave
# 8743   Ethereum         tvl 2025-01-04 00:00:00     18,553,444,286       Aave
# 8744   Ethereum         tvl 2025-01-05 00:00:00     18,744,374,669       Aave
# ...         ...         ...                 ...                ...        ...
# 79414  Ethereum         tvl 2026-01-07 00:00:00      3,632,297,078  SparkLend
# 79415  Ethereum         tvl 2026-01-08 00:00:00      3,419,144,562  SparkLend
# 79416  Ethereum         tvl 2026-01-09 00:00:00      3,532,579,158  SparkLend
# 79417  Ethereum         tvl 2026-01-10 00:00:00      3,551,096,125  SparkLend
# 79418  Ethereum         tvl 2026-01-10 21:49:59      3,539,105,396  SparkLend
#
#       tokens
# 8740     NaN
# 8741     NaN
# 8742     NaN
# 8743     NaN
# 8744     NaN
# ...      ...
# 79414    NaN
# 79415    NaN
# 79416    NaN
# 79417    NaN
# 79418    NaN
#
# [5698 rows x 6 columns]

# %% [markdown]
# # Part 2: Protocol Yeild & Token Distribution

# %%
import requests
import pandas as pd

target_projects = ['aave-v3', 'compound-v3', 'sparklend', 'morpho-v1']

url = "https://yields.llama.fi/pools"
response = requests.get(url)
data = response.json()

records = []

for pool in data.get("data", []):
    if pool.get("project") in target_projects:
        record = {
            "project": pool.get("project"),
            "chain": pool.get("chain"),
            "symbol": pool.get("symbol"),
            "tvlUsd": pool.get("tvlUsd"),
            "apyBase": pool.get("apyBase"),
            "apy": pool.get("apy"),
            "apyMean30d": pool.get("apyMean30d"),
            "predictedClass": pool.get("predictions", {}).get("predictedClass"),
            "predictedProbability": pool.get("predictions", {}).get("predictedProbability"),
            "binnedConfidence": pool.get("predictions", {}).get("binnedConfidence"),
        }
        records.append(record)

df_yeild = pd.DataFrame(records)

# %%
pd.set_option('display.float_format', '{:.10f}'.format)

df_yeild_final = df_yeild[df_yeild['symbol'].isin(["WEETH","WSTETH","WBTC","WETH","CBBTC","USDT","USDC",
                                                 "RSETH","WSTETH","WSTETH","ETH",
                                                   "LBTC","USDS" ,"RETH" ,"STEAKUSDC", "GTUSDCP","WBTC"])]

df_yeild_final = df_yeild_final[df_yeild_final['chain'].isin(["Ethereum","Arbitrum","Base","Polygon","Optimism"])]

# %%
df_yeild_final = df_yeild_final.drop(['binnedConfidence','predictedProbability','predictedClass','apyBase'],axis=1)

# %%
df_yeild_final
# Out:
#          project     chain  symbol      tvlUsd          apy   apyMean30d
# 0        aave-v3  Ethereum   WEETH  7288396909 0.0001400000 0.0001800000
# 1        aave-v3  Ethereum  WSTETH  4202360129 0.0086200000 0.0099200000
# 2        aave-v3  Ethereum    WBTC  3825747791 0.0069400000 0.0065500000
# 3        aave-v3  Ethereum    WETH  2556925851 1.2893800000 1.2409600000
# 4      sparklend  Ethereum  WSTETH  2021144015 0.0000000000 0.0000000000
# ..           ...       ...     ...         ...          ...          ...
# 910    morpho-v1  Ethereum    WBTC       14836 0.0000000000 0.0000000000
# 924  compound-v3  Optimism    USDC       12259 0.0000000000 0.0000000000
# 926    morpho-v1  Ethereum    USDC       12085 0.0000000000 0.0000000000
# 929    morpho-v1   Polygon    WETH       11018 0.0000000000 0.0000000000
# 932    morpho-v1      Base   CBBTC       10474 0.0000000000 0.0000000000
#
# [218 rows x 6 columns]

# %%
df_yeild_final.to_csv('df_yeild_final.csv')

# %% [markdown]
# # Part 3:

# %% [markdown]
# ## Witing List:
# - Aave
# - Morpho
# - SparkLend
# - Compound
